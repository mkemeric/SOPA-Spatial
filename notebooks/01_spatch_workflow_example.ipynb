# %% [markdown]
# # SPATCH Workflow Example
#
# Demonstrates the full SPATCH analysis pipeline using the
# **Janesick et al.** breast cancer Xenium dataset.
#
# **Kernel**: Select **SPATCH** before running.

# %% [markdown]
# ## 1. Environment Setup

# %%
import sys, os
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from setup_local_imports import setup_notebook_environment
setup_notebook_environment()

# %%
import spatialdata as sd
import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from spatch_modules import list_modules, run_single_module

# %% [markdown]
# ## 2. Available SPATCH Modules

# %%
for m in list_modules():
    print(f"{m['name']:30s} v{m['version']:8s} [{m['category']:10s}] {m['description']}")

# %% [markdown]
# ## 3. Load SpatialData
#
# Load the pre-processed Xenium dataset (already segmented and aggregated by Sopa).
# Edit `ZARR_PATH` below to match your environment.

# %%
# --- Configure data path ---
# Try local project copy first, fall back to shared mount
ZARR_PATH = 'results/janesick.zarr'
ZARR_SHARED = '/mnt/shared/hannah-aichelman/janesick.zarr'

_local = Path(ZARR_PATH)
if not (_local / 'tables').exists() and Path(ZARR_SHARED).exists():
    ZARR_PATH = ZARR_SHARED
    print(f'Using shared zarr: {ZARR_PATH}')
else:
    print(f'Using local zarr: {ZARR_PATH}')

sdata = sd.read_zarr(ZARR_PATH)
print(sdata)

# %%
adata = sdata.tables['table']
print(f'Cells:  {adata.n_obs:,}')
print(f'Genes:  {adata.n_vars:,}')
print(f'Shapes: {list(sdata.shapes.keys())}')
print(f'Images: {list(sdata.images.keys())}')
print(f'obs columns: {adata.obs.columns.tolist()}')

# %% [markdown]
# ## 4. Preprocessing and QC

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
sc.pl.violin(adata, 'total_counts', ax=axes[0], show=False)
axes[0].set_title('Total Counts')
sc.pl.violin(adata, 'n_genes_by_counts', ax=axes[1], show=False)
axes[1].set_title('Genes per Cell')
sc.pl.violin(adata, 'pct_counts_mt', ax=axes[2], show=False)
axes[2].set_title('Mitochondrial %')
plt.tight_layout()
plt.show()

# %%
print(f'Before: {adata.n_obs:,} cells, {adata.n_vars:,} genes')

sc.pp.filter_cells(adata, min_genes=50)
sc.pp.filter_cells(adata, max_genes=10000)
adata = adata[adata.obs.pct_counts_mt < 25, :].copy()
sc.pp.filter_genes(adata, min_cells=5)

print(f'After:  {adata.n_obs:,} cells, {adata.n_vars:,} genes')

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata
print('Normalized and log-transformed.')

# %% [markdown]
# ## 5. Dimensionality Reduction

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=3000, flavor='seurat_v3')
sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, n_neighbors=15, n_pcs=50)
sc.tl.umap(adata)

print(f'HVGs: {adata.var.highly_variable.sum()}')
print(f'PCA:  {adata.obsm["X_pca"].shape}')

# %% [markdown]
# ## 6. Clustering

# %%
sc.tl.leiden(adata, resolution=0.5, key_added='leiden_0.5')
sc.tl.leiden(adata, resolution=1.0, key_added='leiden_1.0')

print(f'Clusters at res 0.5: {adata.obs["leiden_0.5"].nunique()}')
print(f'Clusters at res 1.0: {adata.obs["leiden_1.0"].nunique()}')

sc.pl.umap(adata, color=['leiden_0.5', 'leiden_1.0'], wspace=0.4)

# %% [markdown]
# ## 7. Spatial Analysis

# %%
sq.gr.spatial_neighbors(adata, coord_type='generic', n_neighs=15)
sq.gr.nhood_enrichment(adata, cluster_key='leiden_0.5')
sq.pl.nhood_enrichment(adata, cluster_key='leiden_0.5', figsize=(8, 8))
plt.title('Neighborhood Enrichment (res 0.5)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 10))
coords = adata.obsm['spatial']
scatter = ax.scatter(coords[:, 0], coords[:, 1],
                     c=adata.obs['leiden_0.5'].cat.codes,
                     cmap='tab20', s=0.3, alpha=0.7)
ax.set_aspect('equal')
ax.set_title('Spatial Distribution')
ax.invert_yaxis()
plt.colorbar(scatter, ax=ax, label='Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. SPATCH Modules
#
# ### 8.1 Cell Shape Metrics
#
# Compute morphological measurements from cell boundaries.

# %%
sdata_updated = run_single_module(
    sdata, 'cell_shape_metrics',
    output_dir='results/spatch_workflow',
    boundaries_key='cellpose_boundaries',
    table_key='table',
)
adata_shapes = sdata_updated.tables['table']

shape_cols = [c for c in adata_shapes.obs.columns
              if c in ['area', 'perimeter', 'circularity', 'eccentricity', 'solidity']]
if shape_cols:
    print(adata_shapes.obs[shape_cols].describe().round(3))

# %% [markdown]
# ### 8.2 CODEX Loader (Optional)
#
# If paired CODEX/PhenoCycler data is available, load it with the `codex_loader` module.
# Skipped here — no CODEX data for this Xenium dataset.

# %%
# Uncomment and update path if CODEX data is available:
#
# sdata_codex = run_single_module(
#     None, 'codex_loader',
#     data_path='/path/to/codex_output',
# )
# print(sdata_codex)

# %% [markdown]
# ## 9. Visualization

# %%
if shape_cols:
    n = min(len(shape_cols), 3)
    fig, axes = plt.subplots(1, n, figsize=(5 * n, 4))
    if n == 1:
        axes = [axes]
    for ax, col in zip(axes, shape_cols[:n]):
        adata_shapes.obs[col].hist(ax=ax, bins=50)
        ax.set_xlabel(col.replace('_', ' ').title())
        ax.set_title(f'{col} Distribution')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 10. Save Results

# %%
OUTPUT_DIR = Path('results/spatch_workflow')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

adata.write(OUTPUT_DIR / 'processed_table.h5ad')
print(f'Saved AnnData to {OUTPUT_DIR / "processed_table.h5ad"}')
print(f'  {adata.n_obs:,} cells, {adata.n_vars:,} genes')
print(f'  Clusters: leiden_0.5={adata.obs["leiden_0.5"].nunique()}, leiden_1.0={adata.obs["leiden_1.0"].nunique()}')
