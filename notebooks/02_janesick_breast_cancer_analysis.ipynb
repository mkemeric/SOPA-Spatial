# %% [markdown]
# # Janesick Breast Cancer — Interactive Analysis
#
# This notebook explores the **Janesick et al. (Nature Communications, 2023)** FFPE human breast cancer
# dataset after processing through the Sopa + SPATCH pipeline.
#
# **Dataset**: ~218,990 cells × 313 genes (post-aggregation)
# **Shapes**: cellpose_boundaries
#
# **Kernel**: Select **SPATCH** before running.

# %% [markdown]
# ## 1. Environment Setup

# %%
import sys, os
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from setup_local_imports import setup_notebook_environment
setup_notebook_environment()

# %%
import spatialdata as sd
import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from spatch_modules import run_single_module

# --- Configure data path ---
ZARR_PATH = 'results/janesick.zarr'
ZARR_SHARED = '/mnt/shared/hannah-aichelman/janesick.zarr'

_local = Path(ZARR_PATH)
if not (_local / 'tables').exists() and Path(ZARR_SHARED).exists():
    ZARR_PATH = ZARR_SHARED
    print(f'Using shared zarr: {ZARR_PATH}')
else:
    print(f'Using local zarr: {ZARR_PATH}')

OUTPUT_DIR = Path('results/janesick_breast_cancer')
FIG_DIR = OUTPUT_DIR / "figures"
FIG_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Load SpatialData

# %%
sdata = sd.read_zarr(ZARR_PATH)
print(sdata)
print()

adata = sdata.tables["table"]
print(f"Cells: {adata.n_obs:,}")
print(f"Genes: {adata.n_vars:,}")
print(f"obs columns: {adata.obs.columns.tolist()[:15]}")

# %% [markdown]
# ## 3. Quality Control

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
sc.pl.violin(adata, 'total_counts', ax=axes[0], show=False)
axes[0].set_title('Total counts')
sc.pl.violin(adata, 'n_genes_by_counts', ax=axes[1], show=False)
axes[1].set_title('Genes per cell')
sc.pl.violin(adata, 'pct_counts_mt', ax=axes[2], show=False)
axes[2].set_title('Mitochondrial %')
plt.tight_layout()
plt.show()

print(adata.obs[['total_counts', 'n_genes_by_counts', 'pct_counts_mt']].describe().round(1))

# %% [markdown]
# ## 4. Filtering and Normalization

# %%
print(f"Before: {adata.n_obs:,} cells, {adata.n_vars:,} genes")

sc.pp.filter_cells(adata, min_genes=50)
sc.pp.filter_cells(adata, max_genes=10000)
adata = adata[adata.obs.pct_counts_mt < 25, :].copy()
sc.pp.filter_genes(adata, min_cells=5)

print(f"After:  {adata.n_obs:,} cells, {adata.n_vars:,} genes")

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata
print("Normalized and log-transformed.")

# %% [markdown]
# ## 5. Dimensionality Reduction and Clustering

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=3000, flavor='seurat_v3')
sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, n_neighbors=30, n_pcs=50)
sc.tl.umap(adata, min_dist=0.3)
sc.tl.leiden(adata, resolution=0.8)

print(f"Leiden clusters: {adata.obs['leiden'].nunique()}")
sc.pl.umap(adata, color='leiden', legend_loc='on data', legend_fontsize=6,
           title='Leiden Clusters')

# %% [markdown]
# ## 6. Spatial Visualization

# %%
fig, ax = plt.subplots(figsize=(12, 12))
coords = adata.obsm['spatial']
cluster_col = 'leiden' if 'leiden' in adata.obs.columns else adata.obs.columns[0]
scatter = ax.scatter(coords[:, 0], coords[:, 1], c=adata.obs[cluster_col].cat.codes,
                     cmap='tab20', s=0.3, alpha=0.7)
ax.set_aspect('equal')
ax.set_title('Spatial Distribution \u2014 Leiden Clusters')
ax.invert_yaxis()
plt.colorbar(scatter, ax=ax, label='Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Marker Genes

# %%
markers = {
    'Tumor': ['FASN', 'CEACAM6', 'MKI67'],
    'Myoepithelial': ['ACTA2', 'KRT15', 'KRT14'],
    'Stromal': ['POSTN', 'COL1A1', 'DCN'],
    'T cells': ['CD3E', 'CD3D', 'IL7R'],
    'Macrophages': ['ITGAX', 'CD68', 'LYZ'],
    'B cells': ['MS4A1', 'CD79A'],
    'Endothelial': ['VWF', 'PECAM1'],
}

# Filter to genes present
markers_present = {k: [g for g in v if g in adata.var_names] for k, v in markers.items()}
markers_present = {k: v for k, v in markers_present.items() if v}

for ct, genes in markers_present.items():
    sc.tl.score_genes(adata, genes, score_name=f'{ct}_score')

score_cols = [f'{ct}_score' for ct in markers_present]
sc.pl.umap(adata, color=score_cols, ncols=4, cmap='viridis', vmax='p99')

# %% [markdown]
# ## 8. Differential Expression

# %%
cluster_col = 'leiden' if 'leiden' in adata.obs.columns else None
if cluster_col:
    sc.tl.rank_genes_groups(adata, groupby=cluster_col, method='wilcoxon')
    sc.pl.rank_genes_groups(adata, n_genes=10, sharey=False)
else:
    print('No leiden column \u2014 run clustering first')

# %% [markdown]
# ## 9. Spatial Statistics

# %%
cluster_col = 'leiden' if 'leiden' in adata.obs.columns else None
if cluster_col and 'spatial' in adata.obsm:
    sq.gr.spatial_neighbors(adata, coord_type='generic', n_neighs=30)
    sq.gr.nhood_enrichment(adata, cluster_key=cluster_col)
    sq.pl.nhood_enrichment(adata, cluster_key=cluster_col, figsize=(8, 8))
    plt.title('Neighborhood Enrichment')
    plt.show()

# %% [markdown]
# ## 10. SPATCH Custom Modules
#
# Run individual SPATCH modules interactively.

# %% [markdown]
# ### 10.1 Cell Shape Metrics

# %%
# Using boundaries: 'cellpose_boundaries'
sdata_updated = run_single_module(
    sdata, 'cell_shape_metrics',
    output_dir=str(OUTPUT_DIR),
    boundaries_key='cellpose_boundaries',
    table_key='table',
)
adata_shapes = sdata_updated.tables['table']

shape_cols = [c for c in adata_shapes.obs.columns
             if c in ['area', 'perimeter', 'circularity', 'eccentricity', 'solidity']]
if shape_cols:
    print(adata_shapes.obs[shape_cols].describe().round(3))

# %% [markdown]
# ## 11. Pipeline Figures

# %%
from IPython.display import Image, display

figs = sorted(FIG_DIR.glob('*.png'))
if figs:
    for png in figs:
        print(f'\n--- {png.name} ---')
        display(Image(filename=str(png), width=800))
else:
    print('No figures found yet.')
    print('Run the pipeline first:')
    print('  spatch run results/janesick.zarr -c configs/janesick_breast_cancer.yaml')

# %% [markdown]
# ## 12. SPATCH Parquet Results

# %%
spatch_dir = OUTPUT_DIR / 'spatch'
parquets = sorted(spatch_dir.glob('*.parquet')) if spatch_dir.exists() else []
if parquets:
    for pq in parquets:
        df = pd.read_parquet(pq)
        print(f'\n=== {pq.name} ({len(df):,} rows \u00d7 {len(df.columns)} cols) ===')
        print(df.head(3))
else:
    print('No parquet outputs found yet.')
    print('Run SPATCH modules first.')

# %% [markdown]
# ## 13. Summary

# %%
print('=' * 70)
print('ANALYSIS SUMMARY')
print('=' * 70)
print(f'Dataset:  Janesick Breast Cancer (FFPE, Xenium)')
print(f'Cells:    {adata.n_obs:,}')
print(f'Genes:    {adata.n_vars:,}')
if 'leiden' in adata.obs.columns:
    print(f'Clusters: {adata.obs["leiden"].nunique()}')
print(f'Tables:   {list(sdata.tables.keys())}')
print(f'Shapes:   {list(sdata.shapes.keys())}')
print('=' * 70)
